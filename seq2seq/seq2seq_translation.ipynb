# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ```
# function ClickConnect() {
#     var buttons = document.querySelectorAll("colab-dialog.yes-no-dialog paper-button#cancel");
#     buttons.forEach(function(btn) {
#         btn.click();
#     });
#     console.log("1분마다 자동 재연결");
#     document.querySelector("colab-toolbar-button#connect").click();
# }
# setInterval(ClickConnect,1000*60);
# ```

# %%
# %matplotlib inline

# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random
import pandas as pd

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

device = torch.device("cpu")
#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # 데이터 파일 로딩

# %%
# SOS - 문장의 시작
# EOS - 문장의 끝
SOS_token = 0
EOS_token = 1

# 충분히 길게 -> 합니다 문제 해결?
MAX_LENGTH = 512

class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2  # SOS 와 EOS 포함

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %% [markdown]
# 데이터 준비를 위한 전체 과정:
#
# -  데이터 파일을 읽습니다.
# -  영어-한국어 쌍을 생성합니다.
# -  쌍을 이룬 문장들로 단어 리스트를 생성합니다.

# %%
def readLangs(lang1, lang2, reverse=False):
    print("Reading lines...")

    # 파일을 읽고 문장만 분리

    # MS + Watcom 에러 메세지 데이터
    '''
    ms = pd.read_csv('ms_watcom.csv')
    eng_kor = pd.read_csv('eng_kor_news.csv')
    df1 = ms[['Q', 'A']]
    df2 = eng_kor[['영어', '한국어']]
    df2.columns = ['Q', 'A']
    df = pd.concat([df1, df2])
    '''
    data = pd.read_csv('/content/gdrive/MyDrive/different_data.csv')
    df = data[['Q', 'A']]

    # 모든 줄을 쌍으로 분리
    pairs = df.values.tolist()

    # Lang 인스턴스 생성
    # pairs = [list(reversed(p)) for p in pairs]
    input_lang = Lang(lang1)
    output_lang = Lang(lang2)

    return df, input_lang, output_lang, pairs

# %%
def prepareData(lang1, lang2, reverse=False):
    df, input_lang, output_lang, pairs = readLangs(lang1, lang2, reverse)
    print("Read %s sentence pairs" % len(pairs))
    print("Counting words...")

    try:
        for pair in pairs:
            input_lang.addSentence(pair[0])
            output_lang.addSentence(pair[1])
    except AttributeError:
        print(pair)

    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    return df, input_lang, output_lang, pairs

df, input_lang, output_lang, pairs = prepareData('eng', 'kor', False)
print(df.head())
# Out:
# Reading lines...
# Read 11730 sentence pairs
# Counting words...
# Counted words:
# eng 18619
# kor 38513
#                                                    Q  \
# 0  The initialization unit 440 may include a thir...
# 1  It will be possible to transform the startup e...
# 2  1A shows a V2V operation, (b) a V2I operation,...
# 3  The other person registration database 370 may...
# 4  Meanwhile, when the selection of the target ob...
#
#                                                    A
# 0  상기 초기화부(440)는 제 3 트랜지스터(T3) 및 제 4 트랜지스터(T4)를 포...
# 1                         창업생태계를 민간 주도로 전환할 수 있게 된다.
# 2  도 1의 (a)는 V2V 동작, (b)는 V2I 동작, (c)는 V2P 동작을 나타낸다.
# 3  타인 등록 데이터베이스(370)는 한 명 또는 복수 명의 타인에 대한 등록 데이터를...
# 4  한편, 제어부(130)는 대상객체(510)의 선택이 해제되면 선택속성의 복사를 해제...

# %% [markdown]
# # Seq2Seq 모델

# %% [markdown]
# # 인코더
#
# 인코더는 입력 문장의 모든 단어에 대해 어떤 값을 출력하는 RNN입니다.

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        output, hidden = self.gru(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# # 디코더
#
# 디코더는 인코더 출력 벡터를 받아서 번역을 생성하기 위한 단어 시퀀스를
# 출력합니다.

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden):
        output = self.embedding(input).view(1, 1, -1)
        output = F.relu(output)
        output, hidden = self.gru(output, hidden)
        output = self.softmax(self.out(output[0]))
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# ## Attention 디코더
#
# 문맥 벡터만 인코더와 디코더 사이로 전달 된다면, 단일 벡터가 전체 문장을
# 인코딩 해야하는 부담을 가지게 됩니다.
#
# Attention은 디코더 네트워크가 자기 출력의 모든 단계에서 인코더 출력의
# 다른 부분에 "집중" 할 수 있게 합니다. 첫째 *Attention 가중치* 의 세트를
# 계산합니다. 이것은 가중치 조합을 만들기 위해서 인코더 출력 벡터와
# 곱해집니다. 그 결과(코드에서 ``attn_applied``)는 입력 시퀀스의
# 특정 부분에 관한 정보를 포함해야하고 따라서 디코더가 알맞은 출력
# 단어를 선택하는 것을 도와줍니다.
#
# 어텐션 가중치 계산은 디코더의 입력 및 은닉 상태를 입력으로
# 사용하는 다른 feed-forwad 계층인 ``attn`` 으로 수행됩니다.

# %%
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.gru = nn.GRU(self.hidden_size, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, self.output_size)

    def forward(self, input, hidden, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        attn_weights = F.softmax(
            self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
        attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                 encoder_outputs.unsqueeze(0))

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = F.relu(output)
        output, hidden = self.gru(output, hidden)

        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, attn_weights

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# # 학습

# %% [markdown]
# ## 학습 데이터 준비
#
# 학습을 위해서, 각 쌍마다 입력 Tensor(입력 문장의 단어 주소)와
# 목표 Tensor(목표 문장의 단어 주소)가 필요합니다. 이 벡터들을
# 생성하는 동안 두 시퀀스에 EOS 토큰을 추가 합니다.

# %%
def indexesFromSentence(lang, sentence):
    ret = []
    for word in sentence.split(' '):
        try:
            ret.append(lang.word2index[word])
        except:
            pass

    return ret
    # return [lang.word2index[word] for word in sentence.split(' ')]

def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)


def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

# %% [markdown]
# ## 모델 학습

# %%
teacher_forcing_ratio = 0.5


def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing 포함: 목표를 다음 입력으로 전달
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing

    else:
        # Teacher forcing 미포함: 자신의 예측을 다음 입력으로 사용
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # 입력으로 사용할 부분을 히스토리에서 분리

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return target_length / loss.item()
    # return loss.item() / target_length

# %% [markdown]
# 현재 시간과 진행률%을 고려해 경과된 시간과 남은 예상
# 시간을 출력하는 헬퍼 함수

# %%
import time
import math


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %% [markdown]
# 전체 학습 과정
#
# -  타이머 시작
# -  optimizers와 criterion 초기화
# -  학습 쌍의 세트 생성
# -  도식화를 위한 빈 손실 배열 시작

# %%
def trainIters(encoder, decoder, n_iters, print_every=1000, plot_every=100, save_every=1000, learning_rate=0.01):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # print_every 마다 초기화
    plot_loss_total = 0  # plot_every 마다 초기화

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    
    training_pairs = [tensorsFromPair(random.choice(pairs))
                      for i in range(n_iters)]
    criterion = nn.NLLLoss()

    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        input_tensor = training_pair[0]
        target_tensor = training_pair[1]

        loss = train(input_tensor, target_tensor, encoder,
                     decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        plot_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * 100, print_loss_avg))
            
            print("Saving model...")
            torch.save(encoder.state_dict(), "/content/gdrive/MyDrive/seq2seq_encoder.pt")
            torch.save(decoder.state_dict(), "/content/gdrive/MyDrive/seq2seq_decoder.pt")
            

        if iter % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0


    showPlot(plot_losses)

# %% [markdown]
# ## 결과 도식화

# %%
import matplotlib.pyplot as plt
# plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np


def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # 주기적인 간격에 이 locator가 tick을 설정
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)

# %% [markdown]
# # 평가

# %%
def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],
                                                     encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            decoder_attentions[di] = decoder_attention.data
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(output_lang.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words, decoder_attentions[:di + 1]

# %%
# 학습 데이터 셋에 있는 랜덤 문장으로 평가
def evaluateRandomly(encoder, decoder, n=10):
    for i in range(n):
        pair = random.choice(pairs)
        output_words, attentions = evaluate(encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)
        print('>', pair[0])
        print('=', pair[1])
        print('<', output_sentence)
        print('')

def evaluateSentence(encoder, decoder, sentence):
    print('>', sentence)
    output_words, attentions = evaluate(encoder, decoder, sentence)
    output_sentence = ' '.join(output_words)
    print('<', output_sentence)
    print('')

# %% [markdown]
# # 학습

# %%
import os

ENCODER_PATH = "/content/gdrive/MyDrive/seq2seq_encoder.pt"
DECODER_PATH = "/content/gdrive/MyDrive/seq2seq_decoder.pt"

hidden_size = 256

encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)
attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)

# 모델 불러오기
if os.path.isfile(ENCODER_PATH) and os.path.isfile(DECODER_PATH):
    print("Load model...")
    encoder1.load_state_dict(torch.load(ENCODER_PATH))
    attn_decoder1.load_state_dict(torch.load(DECODER_PATH))

# trainIters(encoder1, attn_decoder1, 30000, print_every=5000, save_every=10000)
# trainIters(encoder1, attn_decoder1, 60000, print_every=5000, save_every=10000)
# trainIters(encoder1, attn_decoder1, 100000, print_every=5000, save_every=10000)
# trainIters(encoder1, attn_decoder1, 100, print_every=10)
# Out:
# Load model...

# %%
def evaluateByGCC(encoder, decoder, n=10):
    df = pd.read_csv('GCC errors.csv')
    for item in df.itertuples():
      evaluateSentence(encoder, decoder, item[1])
      # print(item[1])

evaluateByGCC(encoder1, attn_decoder1)
# Out:
# > `##' at end of macro definition
# < 따라서, 원격 경우 있는 사용자가 있는 있는 있다. <EOS>
#
# > `##' at start of macro definition
# < 본 실시예에서, 있어서, 시스템은 중 하나인 따라 특정 시간 있다. <EOS>
#
# > `#elif' after `#else'
# < 이는 경우 주 주 대한 않는 있다. 있다. <EOS>
#
# > #error XXX
# < 이러한 경우 경우 대한 대한 있는 있다. 있다. <EOS>
#
# > `#XXX' not within a conditional
# < 이러한 경우 가장 않은 않은 않은 않은 것으로 위해 것이 바람직하다. 있다. <EOS>
#
# > `#include' expects "FILENAME" or <FILENAME>
# < 또는 또는 또는 또는 또는 또는 또는 또는 또는 유사한 있다. <EOS>
#
# > `#' operator is not followed by a macro argument name
# < 이를 경우 상기 대한 의해 의해 의해 <EOS>
#
# > ANSI C requires a named argument before `...'
# < 디지털 관련 또한 또한 대한 관련 것으로 가지 것으로 것으로 나타났다. <EOS>
#
# > arithmetic on pointer to an incomplete type
# < 디지털 지연 따르면, 주행 기능을 따라 달라질 수 있다. <EOS>
#
# > attempt to take address of bit-field structure member `XXX'
# < 상기 광 내지 내지 도 내지 사이에 사이에 하나를 있다. <EOS>
#
# > badly punctuated parameter list in `#define'
# < 이러한 실시예에서, 수신 수신 기초하여 수신 내에 내에 내에 의해 <EOS>
#
# > break statement not within loop or switch
# < 이 경우 또는 또는 또는 않는 때 또는 또는 것으로 <EOS>
#
# > called object is not a function
# < 이러한 경우 경우 의해 의해 의해 있다. 수 <EOS>
#
# > case label not within a switch statement
# < 이러한 실시예에서, 의해 의해 의해 의해 의해 <EOS>
#
# > character constant too long
# < 디지털 디지털 디지털 디지털 디지털 디지털 모두 있다. <EOS>
#
# > char-array initialized from wide string
# < 그 경우 그 경우 방송 위해 방송 있는 <EOS>
#
# > conflicting types for `XXX'
# < 여기서 대한 대한 위한 대한 위한 대한 위한 있다. 있다. <EOS>
#
# > continue statement not within a loop
# < 특히 경우 경우 가장 때 의해 의해 것이 것이 있다. <EOS>
#
# > declaration of `XXX' as array of voids
# < 두 중 중 중 중 중 중 어느 중 어느 하나의 <EOS>
#
# > default label not within a switch statement
# < 이러한 실시예에서, 상기 않은 의해 의해 의해 검출될 않는다. <EOS>
#
# > dereferencing pointer to incomplete type
# < 따라서 기준 내지 내지 있는 내지 있다. 있다. <EOS>
#
# > duplicate case value
# < 이러한 경우 통해 대한 모두 모두 있다. <EOS>
#
# > empty character constant
# < 이하에서는 단위의 장치(100)는 장치(100)는 대한 대한 대한 위한 디스플레이 <EOS>
#
# > empty file name in `#include'
# < 복수의 바와 같이, 복수의 바와 같이 같은 복수의 <EOS>
#
# > empty #if expression
# < 다른 예를 들어 다른 예를 들어 위해 동작을 <EOS>
#
# > enumerator value for `xxx' not integer constant
# < 이러한 단위의 대한 대한 대한 대한 위한 대한 것으로 것으로 <EOS>
#
# > function `XXX' is initialized like a variable
# < 이를 위해, 경우 있는 현재 있는 현재 있다. <EOS>
#
# > incompatible type for argument N of `XXX'
# < 두 장치는 대한 대한 대한 대한 특정 대한 위한 있다. 수 있다. <EOS>
#
# > incompatible types in assignment
# < 본 연구에서는 특정 바와 따라 가상 위해 <EOS>
#
# > invalid format `#line' directive
# < 네트워크 네트워크 네트워크 네트워크 네트워크 및 네트워크 <EOS>
#
# > invalid #-line
# < 이를 위해, 및 및 위해 위해 등을 <EOS>
#
# > invalid initializer
# < 이를 위해, 및 위해 그 때 등을 <EOS>
#
# > invalid macro name `defined'
# < 이를 위해, 위해 및 위해 위해 있는 <EOS>
#
# > invalid macro name `XXX'
# < 이를 위해, 위해 그 위해 데이터를 있는 것이다. <EOS>
#
# > invalid operands to binary X
# < 상기 정보 경우 정보가 상기 위해 유사한 <EOS>
#
# > invalid preprocessing directive name
# < 상기 상기 상기 및 상기 따라 상기 <EOS>
#
# > invalid use of undefined type `XXX'
# < 기존 중 중 중 중 중 하나인 등을 모두 있다. <EOS>
#
# > invalid type argument of `unary *'
# < 두 장치는 중 중 중 하나인 따라 특정 것이 있다. 있다. <EOS>
#
# > macro or `#include' recursion too deep
# < 이러한 또는 또는 또는 또는 따라 또는 또는 따라 수 있다. <EOS>
#
# > multiple default labels in one switch
# < 하나의 실시예에서, 복수의 중 하나의 중 하나의 하나의 하나의 중 하나의 <EOS>
#
# > negative width in bit-field `XXX'
# < 특히 경우 수신 가지 가지 특히 특히 <EOS>
#
# > No such file or directory
# < 저장 또는 또는 또는 또는 또는 또는 등의 또는 등의 또는 다른 <EOS>
#
# > numeric constant contains digits beyond the radix
# < 이를 통해 상호 의해 사이에 사이에 있다. 수 있다. <EOS>
#
# > parameter `XXX' is initialized
# < 디지털 결과 동작은 도 3의 중 하나인 것으로 <EOS>
#
# > parameter name omitted
# < 디지털 디지털 디지털 디지털 대한 대한 위해 <EOS>
#
# > parse error
# < 이러한 단말(200)은 가장 대응하는 애플리케이션 애플리케이션 생성하는 <EOS>
#
# > parse error before `XXX'
# < 한편, 이동 통해 통해 관련 선택 선택 있는 것으로 <EOS>
#
# > possible real start of unterminated constant
# < 이하에서는 본 발명의 있어서, 실시예에 따른 따른 의해 의해 영향을 <EOS>
#
# > redeclaration of `XXX'
# < 두 장치는 따라 중 하나인 따라 특정 있다. 수 있다. <EOS>
#
# > redefinition of `XXX'
# < 두 말해, 두 가지 따라 특정 따라 있다. 수 있다. <EOS>
#
# > register name not specified for `XXX'
# < 이에 대한 대한 대한 위한 대한 위한 대한 위한 있다. 있다. <EOS>
#
# > request for member `XXX' in something not a structure or union
# < 이러한 바와 바와 같이, 예를 들어 대한 또는 특히 대한 정보를 또는 있다. <EOS>
#
# > `sizeof' applied to a bit-field
# < 이 경우 그 경우 신호를 의해 <EOS>
#
# > storage size of `XXX' isn't known
# < 이는 말해, 데이터 단위의 의해 의해 따라 있다. <EOS>
#
# > structure has no member named `XXX'
# < 따라서, 장치는 생성된 생성된 따라 따라 수 수 <EOS>
#
# > top-level declaration of `XXX' specifies `auto'
# < 이 경우 중 중 중 하나인 따라 있다. <EOS>
#
# > too few arguments to function `XXX'
# < 디지털 디지털 경우 디지털 가지 디지털 가지 <EOS>
#
# > too many arguments to function `XXX'
# < 이 경우 경우 경우 기능을 데 데 <EOS>
#
# > typedef `XXX' is initialized
# < 따라서 다른 경우 전체 대한 있는 것으로 <EOS>
#
# > unbalanced `#endif'
# < 이러한 실시예에서, 상기 대한 대한 때 따라 수 있다. <EOS>
#
# > undefined or invalid # directive
# < 이를 또는 또는 또는 또는 또는 또는 또는 유사한 <EOS>
#
# > union has no member named `XXX'
# < 우리는 생성된 생성된 값을 기초하여 현재 결정할 수 <EOS>
#
# > unterminated character constant
# < 이에 따라, 장치(100)는 장치(100)는 대한 의해 의해 있다. <EOS>
#
# > unterminated comment
# < 제1 1 예를 들면, 있는 애플리케이션 있는 것으로 있다. <EOS>
#
# > unterminated `#if' conditional
# < 본 연구의 및 위해 관한 있는 관한 것이다. <EOS>
#
# > unterminated macro call
# < 단말은 컨텐츠 해당 해당 위해 해당 따라 수 수 <EOS>
#
# > unterminated string or character constant
# < 또는 또는 또는 또는 또는 또는 또는 또는 또는 또는 또는 <EOS>
#
# > variable or field `XXX' declared void
# < 이에 따라, 또는 송신 또는 또는 이상의 또는 또는 또는 <EOS>
#
# > void value not ignored as it ought to be
# < 보안 경우 경우 대한 대한 경우 보안 하는 하는 하는 하는 하는 있다. <EOS>
#
# > `XXX' declared as function returning an array
# < 두 경우 경우 기능을 가지 가지 기능을 가지 가지 것이 가능한 것이 가능한 한 있다. <EOS>
#
# > `XXX' defined as wrong kind of tag
# < 이러한 장에서는 내지 도 3의 따라 따라 따라 수 있다. 있다. 있다. <EOS>
#
# > `XXX' has both `extern' and initializer
# < 또 다른 예로, 및 환경 사이의 사이의 <EOS>
#
# > XXX: No such file or directory
# < 저장 또는 또는 또는 또는 또는 등의 또는 또는 등의 또는 다른 <EOS>
#
# > `XXX' previously declared here
# < 본 실시예에서, 관련된 도 데이터를 또는 또는 유사한 데이터를 있다. <EOS>

# %%
# 다른 컴파일러의 오류 메시지로 테스트

def evaluateByMars(encoder, decoder, n=10):
    df = pd.read_csv('Digital Mars Compile errors.csv')
    for item in df.itertuples():
      evaluateSentence(encoder, decoder, item[2])
      # print(item[1])

evaluateByMars(encoder1, attn_decoder1)
# Out:
# > 'identifier' is a member of 'identifier' and 'identifier'
# < 그 경우 그 중 하나인 및 및 및 있다. 수 있다. <EOS>
#
# > 'identifier' is a pure virtual function
# < 가상 가상 가상 가상 가상 가상 가상 가상 <EOS>
#
# > 'identifier' is already defined
# < 이러한 경우 주 경우 작은 한 있다. <EOS>
#
# > 'identifier' is a virtual base class of 'identifier'
# < 가상 가상 가상 위해 가상 위해 가상 가상 가상 위해 가상 <EOS>
#
# > 'identifier' is far
# < 이에 따라, 경우 경우 가장 많이 것으로 있다. <EOS>
#
# > 'identifier' is not a class template
# < 가장 가장 가장 가장 가장 가장 가장 것으로 결정할 수 있다. <EOS>
#
# > 'identifier' is not a constructor
# < 이러한 결과 경우 않은 않은 않은 않은 것으로 <EOS>
#
# > 'identifier' is not a correct struct
# < 이러한 이러한 대한 대한 대한 의해 것으로 <EOS>
#
# > 'identifier' is not a member of enum 'identifier'
# < 가장 가장 가장 가장 한 한 있다. <EOS>
#
# > 'identifier' is not a member of struct 'identifier'
# < 가장 가장 가장 가장 가장 한 있는 것이 있다. <EOS>
#
# > 'identifier' is not a member of forward referenced struct 'identifier'
# < 가장 가장 가장 가장 가장 가장 많이 것으로 것으로 나타났다. <EOS>
#
# > 'identifier' is not a struct or a class
# < 이를 또는 또는 또는 또는 또는 또는 또는 또는 있다. <EOS>
#
# > 'identifier' is not in function parameter list
# < 디지털 분야의 경우 기능을 가지 기능을 것으로 <EOS>
#
# > 'identifier' is not a variable
# < 이에 따라, 경우 큰 때 큰 큰 보다 된다. <EOS>
#
# > 'identifier' must be a base class
# < 이에 따라, 대한 대한 대한 대한 것으로 <EOS>
#
# > 'identifier' must be a class name preceding '::'
# < 센서 센서 센서 관한 것이다. <EOS>
#
# > 'identifier' must be a public base class of 'identifier'
# < 이 경우 높은 위해 있는 있는 높은 <EOS>
#
# > 'identifier' previously declared as something else
# < 본 발명이 따르면 바와 같이 있는 있는 있는 것이다. <EOS>
#
# > identifier storage class is illegal in this context
# < 본 메모리 본 발명에 따라 메모리 있는 수 있다. 수 <EOS>
#
# > number actual arguments expected for identifier
# < 이 경우 경우 대한 대해 대해 대해 대해 <EOS>
#
# > number exceeds maximum of number parameters
# < 이 경우 주 대한 대한 때 대한 있다. 있다. 있다. <EOS>
#
# > number operands expected for the identifier instruction
# < 이 경우 대한 대한 대한 서비스 <EOS>
#
# > ':' expected
# < 이러한 실시예에서, 경우 있는 있는 있는 검색 있다. <EOS>
#
# > '::' or '(' expected after class 'identifier'
# < 다른 실시예에서, 또는 또는 또는 또는 또는 다른 또는 있다. 있다. 있다. <EOS>
#
# > ';' expected
# < 이러한 실시예에서, 경우 있는 있는 있는 검색 있다. <EOS>
#
# > '
# < 이러한 실시예에서, 상기 대한 대한 따라 수 있다. 있다. <EOS>
#
# > ']' expected
# < 이러한 실시예에서, 경우 있는 있는 있는 있는 있다. <EOS>
#
# > '(' expected
# < 이러한 실시예에서, 경우 있는 있는 있는 검색 있다. <EOS>
#
# > ')' expected
# < 이러한 실시예에서, 경우 있는 있는 있는 검색 있다. <EOS>
#
# > '{' expected
# < 이러한 실시예에서, 경우 있는 있는 있는 검색 있다. <EOS>
#
# > '}' expected
# < 이러한 실시예에서, 경우 있는 있는 있는 검색 있다. <EOS>
#
# > '{' or tag identifier expected
# < 이 경우 또는 또는 또는 또는 또는 또는 유사한 결정될 있다. <EOS>
#
# > '='
# < 이러한 경우 상기 대한 대한 따라 수 있다. 있다. <EOS>
#
# > // comments are not ANSI C
# < 이러한 기준 기준 네트워크 대한 때 있다. 있다. 있다. <EOS>
#
# > ## cannot appear at beginning or end
# < 햅틱 실시예에서, 또는 또는 또는 또는 또는 또는 햅틱 또는 수 있다. <EOS>
#
# > # must be followed by a parameter
# < 디지털 디지털 단일 의해 의해 의해 의해 있다. <EOS>
#
# > '#else' or '#elif' found without '#if'
# < 그 경우 또는 또는 또는 또는 또는 또는 유사한 있다. 있다. <EOS>
#
# > '#endif' found without '#if'
# < 본 연구에서는 사용자가 새로운 통해 다른 시스템 영향을 모두 있다. <EOS>
#
# > #include <typeinfo.h> in order to use RTTI
# < 이러한 경우 내지 있는 내지 있는 있는 위해 있는 것이다. <EOS>
#
# > #pragma pack(pop) does not have corresponding push
# < 이 때, 선택 의해 해당 해당 해당 <EOS>
#
# > '<' expected following cast
# < 이러한 다른 경우 대한 있는 있는 있다. 있다. <EOS>
#
# > '<' expected following 'identifier'
# < 이러한 다른 대한 등 대한 있는 있다. 있다. <EOS>
#
# > '>' expected
# < 이러한 실시예에서, 경우 있는 가장 있는 검색 있다. <EOS>
#
# > 0 expected
# < 이러한 실시예에서, 및 있는 검색 때 및 일부 및 있다. <EOS>
#
# > 0 or 1 expected
# < 이러한 실시예에서, 또는 또는 또는 또는 또는 유사한 또는 유사한 결정될 것이다. <EOS>
#
# > a '...' handler must be the last one for a try-block
# < 그 경우 중 한 한 한 한 있다. <EOS>
#
# > a catch must follow a try-block
# < 그 결과 형태로 형태로 이용하여 형태로 형태로 <EOS>
#
# > access declaration must be in public or protected section
# < 그 경우 예를 들면, 대해 위한 대해 대해 대해 위한 대해 대해 위한 있다. <EOS>
#
# > a derived class member has the same name identifier
# < 이 때, 상기 의해 의해 의해 있다. 수 있다. <EOS>
#
# > alignment must be a power of 2
# < 이러한 방법은 경우 전반적인 의해 의해 따라 <EOS>
#
# > alloca() cannot be used in Windows functions
# < 서비스 경우 정보는 정보는 서비스 정보는 서비스 서비스 서비스 함께 있다. <EOS>
#
# > already seen initializer for 'identifier'
# < 이에 대한 예를 들면, 대한 위한 위해 대한 있다. 있다. <EOS>
#
# > ambiguous reference to base class 'identifier'
# < 이 경우 내지 내지 대한 있는 대한 있다. <EOS>
#
# > ambiguous reference to function
# < 디지털 다양한 내지 내지 따른 따른 따른 서비스 <EOS>
#
# > ambiguous type conversion
# < 이러한 동영상 이전 관한 기능을 가지 및 일부 기능을 수행한다. <EOS>
#
# > argument of type 'identifier' to copy constructor
# < 상기 내지 내지 내지 내지 내지 내지 내지 것이 것이 것이 있다. <EOS>
#
# > argument to postfix ++ or --must be int
# < 보안 실시예에서, 또는 또는 또는 또는 또는 또는 또는 또는 사용될 것이다. 있다. <EOS>
#
# > array dimension must be > 0
# < 이에 따라, 상기 경우 의해 의해 및 있다. <EOS>
#
# > array of functions is illegal
# < 이하에서는 경우 경우 경우 대한 같이 있다. 있다. 것으로 <EOS>
#
# > array of functions or refs is illegal
# < 이하에서는 경우 경우 경우 위한 중 사용될 있다. <EOS>
#
# > array or pointer required before '['
# < 이하에서는 중 하나 이상의 또는 중 중 또는 유사한 중 하나를 <EOS>
#
# > assembler opcode expected
# < 이러한 실시예에서, 경우 있는 검색 있는 검색 있다. <EOS>
#
# > assignment to 'this' is obsolete
# < 이러한 생성된 내지 의해 의해 의해 <EOS>
#
# > at least one parameter must be a class or a class&
# < 적어도 적어도 하나 이상의 적어도 적어도 하나의 또는 적어도 하나의 중 적어도 하나를 수 있다. <EOS>
#
# > bad -D switch
# < 상기 요청 통해 통해 통해 통해 전송될 <EOS>
#
# > bad file name 'filename'
# < 상기 정보 상기 및 있는 위해 있는 <EOS>
#
# > bad member-initializer for 'identifier'
# < 예를 들어 대한 대한 대한 위한 대한 위한 있다. 있다. <EOS>
#
# > base class 'name' has different ambient memory model
# < 외부 메모리 장치는 플래시 메모리 외부 장치와 <EOS>
#
# > binary exponent part required for hex floating constants
# < 이에 따라, 예를 들면, 필요한 필요한 필요한 필요한 있는 <EOS>
#
# > blank arguments are illegal
# < 향후 관리 특정 함께 의해 의해 있다. 있다. <EOS>
#
# > 'break' is valid only in a loop or switch
# < 그 실시예에서, 또는 또는 또는 또는 따라 또는 또는 그 그 것을 의미한다. <EOS>
#
# > can only delete pointers
# < 온라인 메모리 사용자의 형태로 있는 따라 수 수 있다. 있다. 있다. <EOS>
#
# > can't assign to const variable
# < 따라서 내지 내지 내지 내지 내지 있는 <EOS>
#
# > can't build filespec 'filename'
# < 이에 따라, 경우 서비스를 대한 때 기능을 있다. <EOS>
#
# > can't declare member of another class identifier
# < 또 다른 실시예에서, 복수의 따라 따라 다른 있다. 있다. 있다. 있다. 있다. <EOS>
#
# > can't handle constructor in this context
# < 이 때, 본 발명이 있는 있는 있는 이 이 있다. <EOS>
#
# > can't have unnamed bit fields in unions
# < 이러한 기업은 경우 있는 있는 있는 서로 있다. 있다. <EOS>
#
# > can't open response file
# < 이를 통해 단말 따라 추가 기능을 위해 <EOS>
#
# > can't pass const/volatile object to non-const/volatile member function
# < 객체 생성된 생성된 객체 있는 객체 것으로 <EOS>
#
# > can't return arrays
# < 이러한 방법은 주 주 대한 있는 것으로 <EOS>
#
# > can't take address of register
# < 가장 발생 제2 가장 가장 가능한 동작 및 있다. 수 있다. <EOS>
#
# > can't take sizeof bit field
# < 이에 따라, 선택 대한 대한 선택 선택 연결된다. 있다. <EOS>
#
# > cannot convert identifier* to a private base class identifier*
# < 이를 위해, 대한 대한 대한 위해 대한 있다. 수 수 있다. <EOS>
#
# > cannot create instance of abstract class 'identifier'
# < 이를 위해, 경우 높은 기업의 것으로 것으로 <EOS>
#
# > cannot define parameter as extern
# < 디지털 다른 대한 대한 대한 대한 같은 다른 있다. 있다. 있다. 수 있다. <EOS>
#
# > cannot delete pointer to const
# < 두 내지 내지 내지 내지 내지 내지 있다. <EOS>
#
# > cannot find constructor for class matching
# < 보안 보안 새로운 대한 대한 대한 위한 있다. 있다. 있다. <EOS>
#
# > cannot generate identifier for class 'identifier'
# < 이 때, 대한 대한 대한 대한 대한 있다. 있다. 있다. <EOS>
#
# > cannot generate template instance from -XI identifier
# < 연구 분야의 높은 내 여러 가지 있다. 있다. <EOS>
#
# > cannot have member initializer for 'identifier'
# < 상기 대한 대한 대한 대한 대한 것으로 더 있다. <EOS>
#
# > cannot implicitly convert
# < 디지털 서비스 관한 서비스 따라 서비스 수도 있다. <EOS>
#
# > cannot mix C++ EH with NT structured EH
# < 이는 다른 대한 기반으로 대한 기반으로 기반으로 있다. 수 있다. <EOS>
#
# > cannot raise or lower access to base member 'identifier'
# < 상기 또는 또는 또는 또는 또는 또는 유사한 또는 또는 수 있다. <EOS>
#
# > cannot throw object of 'identifier' not of ambient memory model
# < 메모리 메모리 내부 메모리 외부 중 메모리 메모리 설정될 수 있다. <EOS>
#
# > case number was already used
# < 최근 경우 경우 경우 많이 많이 많이 많이 많이 있다. <EOS>
#
# > casts and sizeof are illegal in preprocessor expressions
# < 본 발명의 실시예는 장치는 기능을 기능을 기능을 있는 기능을 있다. 수 있다. <EOS>
#
# > catch type masked by previous catch
# < 이러한 제안한 의해 의해 의해 의해 의해 의해 의해 <EOS>
#
# > class name identifier expected after ~
# < 이 경우 통해 네트워크 통해 온라인 <EOS>
#
# > code segment too large
# < 통신 장치는 데이터 신호는 데이터 중 적어도 하나를 위한 있다. <EOS>
#
# > comma not allowed in constant expression
# < 따라서, 사용자는 이러한 데이터가 위해 있는 의해 있다. <EOS>
#
# > comments do not nest
# < 이에 따라, 있어서, 모델 않은 않은 않은 않은 않은 않은 것으로 나타났다. <EOS>
#
# > compile all files with -EH to support exception handling
# < 스마트 실시예에서, 관한 스마트 가지 가지 있는 있다. <EOS>
#
# > compile all files with -ER to support RTTI
# < 이하에서는 다양한 중 중 중 하나인 <EOS>
#
# > const or reference 'identifier' needs initializer
# < 이를 위해, 따른 또는 또는 또는 또는 또는 또는 유사한 있다. <EOS>
#
# > constant expression does not fit in switch type
# < 이러한 단위의 중 중 중 중 하나인 전체 중 것으로 것으로 보인다. <EOS>
#
# > constant initializer expected
# < 이러한 방법은 경우 있는 있는 있는 있는 것으로 <EOS>
#
# > 'continue' is valid only in a loop
# < 특히 경우 그 경우 기능을 의해 것을 것이 있다. <EOS>
#
# > conversion of int to far or handle pointer
# < 그 발생 발생 또는 또는 또는 또는 등을 또는 등을 <EOS>
#
# > data or code defined in precompiled header
# < 데이터 저장 데이터가 데이터가 데이터 데이터가 데이터가 데이터 또는 데이터를 <EOS>
#
# > declarator for 0 sized bit field
# < 이에 따라, 복수의 복수의 대한 대한 포함하는 선택 포함한다. 포함한다. <EOS>
#
# > 'default:' is already used
# < 보안 방법은 경우 의해 의해 의해 의해 있다. <EOS>
#
# > different configuration for precompiled header
# < 상이한 다른 예를 들면, 위한 상이한 위한 대해 대해 위한 데이터를 저장할 있다. <EOS>
#
# > divide by 0
# < 이에 따라, 경우 의해 의해 의해 의해 의해 있다. <EOS>
#
# > duplicate direct base class 'identifier'
# < 이를 위해, 대한 대한 대한 위한 위해 대한 것으로 <EOS>
#
# > DS is not equal to DGROUP
# < 이러한 내지 내지 의해 의해 의해 <EOS>
#
# > duplicate file names 'filename'
# < 이 경우 이동 시스템은 중 하나인 있는 있다. <EOS>
#
# > empty declaration
# < 다른 구현들에서, 따르면, 사용자의 입력에 의해 의해 <EOS>
#
# > end of file found before '#endif'
# < 현재 중 통해 통해 통해 중 중 하나인 나타낸다. <EOS>
#
# > end of file found before end of comment
# < 이 중 중 중 중 중 중 중 중 어느 하나의 중 나타낸다. <EOS>
#
# > end of line expected
# < 이에 따라, 경우 내지 내지 내지 내지 있다. 있다. <EOS>
#
# > error writing output file
# < 이 때, 상기 출력 디스플레이 장치는 출력 출력할 <EOS>
#
# > exception specifications must match exactly for each declaration of a function
# < 이 경우 각 기능을 가지 가지 가지 것으로 있다. <EOS>
#
# > expected assembler directive PTR to follow assembler cast
# < 이러한 과정에서 경우 있는 있는 있는 있는 것으로 있다. <EOS>
#
# > expected data def of 'identifier'
# < 데이터 데이터 데이터 데이터의 데이터 데이터 데이터 데이터를 데이터를 데이터를 있다. <EOS>
#
# > exponent expected
# < 이러한 실시예에서, 플래시 메모리 검색 검색 있는 검색 <EOS>
#
# > expression expected
# < 이러한 보호는 가장 있는 있는 있는 있는 검색 있다. <EOS>
#
# > expression must be a pointer
# < 상기 같은 예를 들어 의해 의해 있다. <EOS>
#
# > expression must be a pointer or reference to a polymorphic type
# < 상기 영역은 상기 따라 또는 금속 설정될 수 있다. <EOS>
#
# > external with block scope cannot have initializer
# < 상기 새로운 새로운 대한 대한 수 수 있다. 있다. <EOS>
#
# > '_far16' is only valid in -mf memory model
# < 메모리 메모리 플래시 메모리 의해 메모리 의해 메모리 <EOS>
#
# > '_far16' functions can only be extern
# < 그러한 따라, 특정 대한 대한 있는 대한 정보를 있다. 수 있다. 있다. 있다. 있다. <EOS>
#
# > field 'identifier' must be of integral type
# < 디지털 중 대한 대한 의해 의해 있다. 있다. 있다. <EOS>
#
# > filespec string expected
# < 기존 생성된 기술은 가장 있는 것은 있는 온라인 <EOS>
#
# > __finally or __except expected
# < 이러한 실시예에서, 또는 또는 또는 또는 또는 또는 유사한 또는 유사한 있다. <EOS>
#
# > forward referenced class 'identifier' cannot be a base class
# < 통신 대한 대한 대한 대한 것으로 <EOS>
#
# > function 'identifier' can't be in an anonymous union
# < 이는 경우 경우 있는 있는 있는 있는 있는 있다. 있다. 있다. 있다. <EOS>
#
# > function member 'identifier' has no prototype
# < 이 경우 경우 위치 따라 의해 의해 있다. <EOS>
#
# > function 'identifier' is too complicated to inline
# < 디지털 관련 경우 경우 대한 의해 있도록 있다. <EOS>
#
# > function definition must have explicit parameter list
# < 특히 경우 세 가지 가지 가지 것으로 <EOS>
#
# > function expected
# < 이러한 실시예에서, 검색 검색 검색 검색 검색 있다. <EOS>
#
# > functions can't return arrays or functions
# < 이러한 실시예에서, 상기 정보는 또는 또는 또는 또는 다른 또는 또는 유사한 <EOS>
#
# > GetExceptionCode() only valid in exception filter or handler
# < 컴퓨터 컴퓨터 컴퓨터 컴퓨터 컴퓨터 컴퓨터 컴퓨터 또는 소프트웨어 또는 그 같이 결정될 것이다. <EOS>
#
# > GetExceptionInformation() only valid in exception filter
# < 그 경우 전체 의해 의해 의해 의해 의해 있다. <EOS>
#
# > global anonymous unions must be static
# < 디지털 지연 대한 있는 디지털 사이에 있다. 있다. <EOS>
#
# > hex digit expected
# < 이러한 실시예에서, 경우 있는 의해 있는 것이 있다. 있다. <EOS>
#
# > identifier expected
# < 이 경우 생성된 생성된 기능을 개의 있다. <EOS>
#
# > identifier found in abstract declarator
# < 이러한 생성된 생성된 생성된 경우, 경우, 경우, 메모리에 저장될 수 있다. <EOS>
#
# > identifier is longer than 254 chars
# < 프로세서(120)는 사용자가 사용자가 사용자가 사용자가 않는 않는 것으로 것으로 <EOS>
#
# > identifier or '(declarator) ' expected
# < 이러한 실시예에서, 또는 또는 또는 또는 또는 등의 또는 다른 있다. <EOS>
#
# > illegal addressing mode
# < 본 실시예에서, 디지털 수신 수신 기초하여 수신 것이다. <EOS>
#
# > illegal cast
# < 이하에서는 본 실시예에서, 따른 가상 의해 의해 있다. <EOS>
#
# > illegal character
# < 이에 의해, 대한 정보에 대한 따른 것으로 <EOS>
#
# > illegal combination of types
# < 이와 따라 다양한 형태로 따라 형태로 따라 것이 있다. <EOS>
#
# > illegal constuctor or destructor declaration
# < 일 실시예에서, 또는 또는 또는 또는 또는 또는 또는 있다. 있다. <EOS>
#
# > illegal operand
# < 본 실시예에서, 특정 특정 의해 의해 본 있다. 수 있다. <EOS>
#
# > illegal operand types
# < 이하에서는 특정 특정 특정 특정 특정 제어할 있다. 있다. <EOS>
#
# > illegal pointer arithmetic
# < 이를 위해, 또한 또한 기능을 따라 있다. <EOS>
#
# > illegal return type for operator->()
# < 각 대한 대한 대한 대한 대한 대한 있다. 있다. <EOS>
#
# > illegal type combination
# < 이와 같이 실시예에서, 형태로 있는 있는 기능을 있다. <EOS>
#
# > illegal type for 'identifier' member
# < 디지털 장치는 대한 대한 대한 대한 대한 수 있다. 있다. <EOS>
#
# > illegal type/size of operands for the identifier instruction
# < 이 때, 대한 대한 기능을 따라 의해 있다. <EOS>
#
# > implied return at closing '}' does not return value
# < 즉, 경우 높은 않은 않은 다른 것으로 모두 있다. <EOS>
#
# > initialization of 'identifier' is skipped
# < 이에 따라, 복수의 메모리 의해 의해 의해 의해 있다. 있다. 있다. <EOS>
#
# > initializer for static member must be outside of class def
# < 이하에서는 대한 대한 대한 대한 위한 대한 위한 있다. 것으로 <EOS>
#
# > initializer or function body for dllimport not allowed
# < 또 다른 예를 들면, 대한 또는 또는 금속 또는 또는 유사한 있다. <EOS>
#
# > integer constant expression expected
# < 이러한 방법은 경우 있는 있는 있는 있는 것으로 <EOS>
#
# > integral expression expected
# < 이러한 이러한 경우 가장 있는 의해 의해 있다. <EOS>
#
# > internal error identifier number
# < 이 때, 통해 제2 통해 있는 <EOS>
#
# > invalid instruction set 'set' for memory model 'model'
# < 메모리 장치는 예를 들면, 메모리 동작에 필요한 위한 프로그램 메모리 <EOS>
#
# > invalid reference initialization
# < 이에 따라, 제2 대한 대한 대한 대한 있다. 있다. <EOS>
#
# > invalid storage class for friend
# < 이에 대한 대한 대한 대한 대한 위한 대한 있다. <EOS>
#
# > keyword not supported
# < 여기서 모델 영역에 영역에 않는 한 한 있다. <EOS>
#
# > last line in file had no \n
# < 이 경우 개인 경우 개인 의해 보다 보다 있다. <EOS>
#
# > __leave must be within a __try block
# < 이러한 경우 경우 의해 의해 의해 있다. 있다. <EOS>
#
# > line number expected
# < 이에 따라, 제 2 내지 내지 내지 내지 있다. 있다. <EOS>
#
# > linkage specs are "C"
# < 제 1 관련 제 대한 대한 있다. 수 있다. 있다. <EOS>
#
# > local class cannot have static data member 'identifier'
# < 데이터 데이터 데이터 데이터 데이터 데이터 데이터 데이터 데이터 데이터 데이터 데이터 데이터 데이터를 데이터 데이터 데이터 데이터 데이터 데이터 데이터를 데이터 데이터 데이터 데이터 데이터를 있다. <EOS>
#
# > long long not supported for ANSI or 16 bit compiles
# < 또 다른 예를 들어 대한 또는 금속 있는 또는 사용될 것이다. <EOS>
#
# > lvalue expected
# < 이러한 실시예에서, 경우 있는 있는 있는 검색 있다. <EOS>
#
# > main()
# < 이러한 실시예에서, 상기 대한 따라 의해 있다. 수 있다. <EOS>
#
# > maximum width of number bits exceeded
# < 두 번째 부분 두 개의 두 개의 두 개의 것으로 나타났다. <EOS>
#
# > macro 'identifier' can't be #undef'd or #define'd
# < 이에 따라, 경우 또는 또는 또는 또는 또는 유사한 또는 <EOS>
#
# > malformed template declaration
# < 우리는 발생 대한 가장 대한 것으로 <EOS>
#
# > maximum length of macro text exceeded
# < 이는 컨텐츠 주 있는 대한 대한 따라 있는 것으로 <EOS>
#
# > max of number characters in string exceeded
# < 이에 따라, 컨텐츠 통해 중에서 따라 중에서 따라 유사한 있다. <EOS>
#
# > member 'identifier' can't be same type as struct 'identifier'
# < 동일한 동일한 동일한 동일한 동일한 동일한 동일한 있다. 있다. <EOS>
#
# > member 'identifier' is const but there is no constructor
# < 이는 경우 부분 경우 경우에 의해 의해 있다. <EOS>
#
# > member 'identifier' of class 'identifier' is not accessible
# < 이러한 경우 내지 않은 않은 않은 않은 것으로 나타났다. <EOS>
#
# > member 'identifier' of class 'identifier' is private
# < 이는 위해, 따라 중 하나인 따라 것으로 것으로 있다. <EOS>
#
# > missing '
# < 이러한 원격 상기 시스템 의해 의해 의해 의해 있다. <EOS>
#
# > missing decl-specifier-seq for declaration of 'identifier'
# < 이를 대한 대한 대한 위한 위해 대한 위한 있다. 있다. <EOS>
#
# > must be void operator delete(void *[, size_t]);
# < 이 경우 통해 의해 의해 수 있다. <EOS>
#
# > must use delete[] for arrays
# < 디지털 예를 들면, 대한 대한 위한 대해 대해 대해 대해 대해 있다. <EOS>
#
# > need at least one external def
# < 외부 적어도 하나의 외부 적어도 하나의 하나의 하나의 하나의 적어도 하나의 하나의 있다. <EOS>
#
# > no constructor allowed for class 'identifier'
# < 사용자의 대한 대한 대한 대한 위한 대한 있다. <EOS>
#
# > no definition for static 'identifier'
# < 디지털 지연 대한 대한 있는 대한 것으로 <EOS>
#
# > no identifier for declarator
# < 서비스 서비스 대한 대한 대한 데 데 있다. <EOS>
#
# > no input file specified
# < 입력 입력 입력 입력 입력 입력 입력 입력 입력 <EOS>
#
# > no instance of class 'identifier'
# < 기존 모델은 높은 경우 높은 있는 영향을 영향을 미치는 것으로 판단된다. <EOS>
#
# > no instance of class 'identifier' for member 'identifier'
# < 디지털 디지털 대한 대한 있는 가장 많이 많이 있다. 있다. <EOS>
#
# > no match for function 'identifier'
# < 디지털 결과 따른 개인 방법을 위한 기능을 가지 가지 것으로 나타났다. <EOS>
#
# > no return value for function 'identifier'
# < 이에 따라 디지털 가지 가지 가지 가지 것으로 것으로 나타났다. <EOS>
#
# > no tag name for struct or enum
# < 그 경우 또는 또는 또는 또는 또는 또는 따라 있다. <EOS>
#
# > non-const reference initialized to temporary
# < 전압 내지 내지 내지 내지 내지 내지 있다. <EOS>
#
# > not a struct or union type
# < 이러한 실시예에서, 또는 또는 또는 금속 또는 금속 또는 금속 <EOS>
#
# > not an overloadable operator token
# < 이러한 2는 있어서, 관련 예를 들면, 나타낸다. <EOS>
#
# > not in a switch statement
# < 이러한 실시예에서, 상기 내 통해 않는 한 있다. 있다. <EOS>
#
# > number 'number' is too large
# < 이 경우 경우 경우 대한 위해 있다. <EOS>
#
# > number is not representable
# < 이에 따라, 경우 않은 않은 않은 않은 않은 것으로 나타났다. <EOS>
#
# > object has 0 size
# < 센서 장치는 경우 신호를 채널 값을 신호를 수 <EOS>
#
# > octal digit expected
# < 이러한 실시예에서, 경우 있는 있는 있는 검색 있다. <EOS>
#
# > one argument req'd for member initializer for 'identifier'
# < 하나의 출력 하나의 중 하나의 중 하나의 한 위한 대해 대해 <EOS>
#
# > only classes and functions can be friends
# < 사용자는 및 및 있는 의해 의해 의해 수 수 있다. 수 있다. 있다. <EOS>
#
# > only one identifier is allowed to appear in a declaration appearing in a conditional expression
# < 이러한 생성된 복수의 특정 위해 있는 있는 있는 있는 <EOS>
#
# > operator overload must be a function
# < 이러한 다양한 의해 의해 의해 의해 <EOS>
#
# > out of memory
# < 이에 따라, 메모리 장치는 메모리 중 메모리 <EOS>
#
# > overloaded function 'identifier' has different access levels
# < 다른 장치는 다른 상이한 다른 상이한 다른 전자 전자 수도 있다. 있다. <EOS>
#
# > parameter list is out of context
# < 기존 장에서는 대한 가지 가지 가지 있다. <EOS>
#
# > parameter lists do not match for template 'identifier'
# < 디지털 디지털 대한 위한 대한 위한 대해 대해 위한 대해 <EOS>
#
# > pascal string length number is longer than 255
# < 제1 경우 제1 내지 대한 때 따라 <EOS>
#
# > pointer required before '->'
# < 디지털 관련 중 통해 관련 관련 중 관련 있다. <EOS>
#
# > pointer required before '->' or after '*'
# < 디지털 예를 예를 들면, 예를 들면, 또는 금속 또는 다른 있다. 있다. <EOS>
#
# > pointer to member expected to right of .* or ->*
# < 이를 위해, 위해 또는 또는 또는 유사한 또는 유사한 또는 유사한 또는 있다. <EOS>
#
# > possible extraneous ';'
# < 이를 위해, 장치(100)는 통해 내지 있는 통해 있다. <EOS>
#
# > possible unintended assignment
# < 본 명세서에 기술된 외부 애플리케이션 이용하여 이용하여 <EOS>
#
# > pragma cseg must be at global scope
# < 이하에서는 경우 큰 가장 큰 높은 대한 것으로 있다. <EOS>
#
# > precompiled header compiled with C instead of C++
# < 두 번째 가장 두 가지 두 가지 두 가지 있다. <EOS>
#
# > precompiled header compiled with C++ instead of C
# < 두 번째 복수의 특정 의해 의해 있다. 있다. <EOS>
#
# > prefix opcode must be followed by an assembler opcode
# < 이러한 의한 의한 의해 의해 의해 의해 있다. 의해 있다. <EOS>
#
# > premature end of source file
# < 이 <EOS>
#
# > prototype for 'identifier' should be identifier
# < 이에 따라, 음성 의해 의해 의해 의해 있다. <EOS>
#
# > pure function must be virtual
# < 가상 가상 가상 가상 가상 가상 가상 가상 가상 가상 <EOS>
#
# > qualifier or type in access declaration
# < 또는 또는 또는 또는 또는 또는 또는 또는 또는 또는 유사한 있다. <EOS>
#
# > recursive prototype
# < 제 1 내지 제 2 따라 의해 있다. <EOS>
#
# > redefinition of default parameter
# < 디지털 다른 예를 들어 대한 가지 가지 있다. 있다. <EOS>
#
# > reference to 'identifier' caused a 386 instruction to be generated
# < 이하에서는 경우 전송 대한 따른 대하여 서비스 동작을 있다. <EOS>
#
# > reference must refer to same type or be const
# < 동일한 경우 또는 또는 또는 또는 유사한 또는 유사한 또는 유사한 또는 유사한 결정될 것이다. <EOS>
#
# > return type cannot be specified for conversion function
# < 이 경우 경우 경우 가지 의해 있다. 것으로 있다. <EOS>
#
# > returning address of automatic 'identifier'
# < 이에 따라 여러 가지 있는 있는 있는 및 있다. 수 있다. <EOS>
#
# > segment size is number
# < 이 경우 상기 광 채널 광 연결된다. <EOS>
#
# > should be number parameter(s) for operator
# < 이러한 관련 예를 들면, 예를 들면, 예를 들어 <EOS>
#
# > size of identifier is not known
# < 이는 경우 통해 모든 의해 의해 있다. 있다. <EOS>
#
# > size of type exceeds 64KB
# < 이를 경우 통해 주 대한 따라 영향을 <EOS>
#
# > statement expected
# < 이러한 실시예에서, 경우 있는 가장 있는 검색 있다. <EOS>
#
# > static function 'identifier' can't be virtual
# < 가상 가상 가상 가상 가상 가상 가상 가상 가상 가상 <EOS>
#
# > static or non-member functions can't be const or volatile
# < 디스플레이 실시예에서, 또는 또는 또는 유사한 또는 유사한 또는 유사한 또는 <EOS>
#
# > static variables in inline functions not allowed
# < 이하에서는 경우 정보는 않은 의해 의해 의해 의해 의해 다른 <EOS>
#
# > storage class for 'identifier' can't be both extern and inline
# < 이에 대한 대한 대한 대한 위한 있는 대해 있는 대해 대해 위한 있다. <EOS>
#
# > string expected
# < 기존 생성된 경우 있는 것은 있는 온라인 <EOS>
#
# > struct-declaration-list can't be empty
# < 다른 예에서, 동작은 의해 의해 의해 의해 <EOS>
#
# > template-argument 'identifier' must be a type-argument
# < 그 결과 의해 의해 의해 의해 있다. <EOS>
#
# > template-argument 'identifier' not used in function parameter types
# < 이러한 또한 또한 또한 또한 기능을 기능을 따른 서비스 기능을 있다. <EOS>
#
# > too many errors
# < 두 시스템은 통해 산업 및 산업 위해 <EOS>
#
# > too many initializers
# < 보안 발생 통해 여러 가지 가지 있다. 수 있다. <EOS>
#
# > trailing parameters must have initializers
# < 이를 위해, 대한 대한 대한 사이에 있다. 있다. <EOS>
#
# > __try only valid for -mn memory model
# < 메모리 메모리 플래시 메모리 플래시 의해 위한 프로그램 <EOS>
#
# > type conversions must be members
# < 디지털 경우 대한 있는 의해 의해 의해 있다. 있다. <EOS>
#
# > type is too complex
# < 이는 화면에서 낮은 대한 때 따라 있다. 있다. <EOS>
#
# > type mismatch
# < 상기 광 생성된 따라 따라 따라 수 있다. <EOS>
#
# > type must be a pointer or a reference to a defined class or void*
# < 상기 감지 또는 금속 또는 금속 금속 또는 금속 또는 금속 <EOS>
#
# > type must be void *operator new(size_t [,..]);
# < 그러한 대한 대한 대한 의해 대한 것으로 <EOS>
#
# > type of 'identifier' does not match function prototype
# < 이에 따라 변경 내지 있는 따른 현재 있는 현재 있다. <EOS>
#
# > types may not appear more than once in an exception specification
# < 이러한 인식 인식 인식 경우, 인식 경우, 경우, 정의될 수 수 있다. <EOS>
#
# > unable to open input file 'filename'
# < 입력 입력 입력 입력 입력 입력 입력 입력 입력 <EOS>
#
# > unable to open output file 'filename'
# < 출력 출력 출력 출력 값을 출력할 수 있는 <EOS>
#
# > undefined escape sequence
# < 다른 예를 들면, 대한 대한 다른 있는 것이다. 있다. <EOS>
#
# > undefined identifier 'identifier'
# < 이 때, 통해 제2 의해 있다. 있다. <EOS>
#
# > undefined label 'identifier'
# < 이하에서는 경우 이상의 있는 따른 중 있다. <EOS>
#
# > undefined tag 'identifier'
# < 이러한 보호는 주 및 도 1의 도시된 및 있다. 수 있다. 있다. <EOS>
#
# > undefined use of struct or union
# < 두 또는 또는 또는 또는 또는 따라 또는 또는 또는 등의 또는 있다. <EOS>
#
# > unknown operand type for this floating point instruction
# < 본 발명에 따른 음성 음성 관련된 음성 대한 음성 있다. <EOS>
#
# > union members cannot have ctors or dtors
# < 이는 또는 경우 또는 또는 금속 또는 금속 그룹의 또는 형성될 수 있다. <EOS>
#
# > unrecognized pragma
# < 이러한 경우 상기 대한 대한 따라 수 있다. 있다. <EOS>
#
# > unrecognized parameter 'identifier'
# < 디지털 다른 예를 들면, 대한 위한 의해 있다. <EOS>
#
# > unrecognized preprocessing directive '#identifier'
# < 상기 상기 제2 1 위해 따라 <EOS>
#
# > unrecognized token
# < 다음으로, 수신 처리 있는 대한 있는 있는 <EOS>
#
# > unsupported based type
# < 이 경우 생성된 따라 따라 따라 기반으로 것으로 <EOS>
#
# > unsupported __declspec type
# < 특히, 생성된 중 대한 중 하나인 따라 달라질 수 있다. <EOS>
#
# > unterminated macro argument
# < 이러한 방법은 또한 대한 애플리케이션 위해 특히 <EOS>
#
# > unterminated string
# < 이를 통해 통해 통해 통해 의해 <EOS>
#
# > use delete[] rather than delete[expr]
# < 이는 경우 큰 경우 위해 있는 데이터의 등 등 등 있다. <EOS>
#
# > using operator++() (or --) instead of missing operator++(int)
# < 두 가지 두 가지 사용하여 사용하여 사용하여 사용하여 사용하여 사용하여 사용하여 사용하여 있다. <EOS>
#
# > valid memory models are -m[tsmcrzlvfnpx]
# < 복수의 메모리 복수의 메모리 중 하나인 연결된다. <EOS>
#
# > value of expression is not used
# < 이러한 관련 경우 가장 관련 않는 것으로 것으로 <EOS>
#
# > variable 'identifier' used before set
# < 현재 제공 제공 필요한 필요한 현재 있는 현재 <EOS>
#
# > vectors cannot have initializers
# < 이러한 원격 상기 대한 대한 동일한 동일한 수 있다. <EOS>
#
# > very large automatic
# < 한편, 선택 따라 여러 가지 있는 영향을 영향을 미치는 것으로 보인다. <EOS>
#
# > voids have no value
# < 이 경우 상기 때 따라 때 것을 있다. <EOS>
#
# > voids have no value
# < 이 경우 높은 경우 때 때 것을 <EOS>
#
# > 'while' expected
# < 이러한 실시예에서, 경우 있는 있는 있는 검색 있다. <EOS>

# %%
# 학습데이터에서 랜덤하게 테스트

evaluateRandomly(encoder1, attn_decoder1, n=3)
